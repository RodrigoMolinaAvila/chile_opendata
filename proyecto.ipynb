# %% [markdown]
# # Biblioteca del Congreso Nacional

# %% [markdown]
# - Endpoint: https://datos.bcn.cl/sparql
# - Documentación: https://datos.bcn.cl/es/ontologias/index_html, https://datos.bcn.cl/ontologies/bcn-congress/doc/
# - Consultas: https://datos.bcn.cl/es/endpoint-sparql/documentacion/consultas-sparql

# %% [markdown]
# # InfoProbidad

# %% [markdown]
# - Endpoint: https://datos.cplt.cl/sparql
# - Documentación: https://www.infoprobidad.cl/DatosAbiertos/Ontologia
# - Facet: https://datos.cplt.cl/fct/facet.vsp

# %% [markdown]
# # InfoLobby

# %% [markdown]
# - Endpoint: http://datos.infolobby.cl/sparql
# - Documentación: https://www.infolobby.cl/DatosAbiertos/DocumentacionOntologia
# - Facet: http://datos.infolobby.cl/fct/facet.vsp
